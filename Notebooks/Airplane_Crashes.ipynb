# %% [markdown]
# # Airplanes Classwork

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Airplane_Crashes_and_Fatalities_Since_1908.csv")

# %%
df.count()
# Out:
# Date            5268
# Time            3049
# Location        5248
# Operator        5250
# Flight #        1069
# Route           3562
# Type            5241
# Registration    4933
# cn/In           4040
# Aboard          5246
# Fatalities      5256
# Ground          5246
# Summary         4878
# dtype: int64

# %% [markdown]
# ## Make a column for year & month using apply method
#
# Make sure all values get converted!

# %%
df['year'] = df['Date'].apply(lambda x: int(x[-4:])) #you can use split too, but some dates have separation of dashes instead of slash. 
df['month'] = df['Date'].apply(lambda x: int(x[0:2]))
df.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary  year  month
# 0  During a demonstration flight, a U.S. Army fly...  1908      9
# 1  First U.S. dirigible Akron exploded just offsh...  1912      7
# 2  The first fatal airplane accident in Canada oc...  1913      8
# 3  The airship flew into a thunderstorm and encou...  1913      9
# 4  Hydrogen gas which was being vented was sucked...  1913     10

# %%
df.count()
# Out:
# Date            5268
# Time            3049
# Location        5248
# Operator        5250
# Flight #        1069
# Route           3562
# Type            5241
# Registration    4933
# cn/In           4040
# Aboard          5246
# Fatalities      5256
# Ground          5246
# Summary         4878
# year            5268
# month           5268
# dtype: int64

# %%
df['month'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Remove the Flight #, cn/in columns

# %%
df = df.drop(['Flight #', "cn/In"], axis=1)
df.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#    Aboard  Fatalities  Ground  \
# 0     2.0         1.0     0.0
# 1     5.0         5.0     0.0
# 2     1.0         1.0     0.0
# 3    20.0        14.0     0.0
# 4    30.0        30.0     0.0
#
#                                              Summary  year  month
# 0  During a demonstration flight, a U.S. Army fly...  1908      9
# 1  First U.S. dirigible Akron exploded just offsh...  1912      7
# 2  The first fatal airplane accident in Canada oc...  1913      8
# 3  The airship flew into a thunderstorm and encou...  1913      9
# 4  Hydrogen gas which was being vented was sucked...  1913     10

# %% [markdown]
# ## Which year had the most airplane crashes?

# %%
print("{0} has the most crashes.".format(df['year'].value_counts().index[0]))
# Out:
# 1972 has the most crashes.

# %% [markdown]
# ## Which operator had the most crashes?

# %%
print("{0} Operator has the most crashes.".format(df['Operator'].value_counts().index[0]))
# Out:
# Aeroflot Operator has the most crashes.

# %% [markdown]
# ## Which Route is the least risky?

# %%
indexes = list((df['Route'].value_counts()).index)
index_vals = (df['Route'].value_counts()).tolist()
print("Least Risky Routes are\n", indexes[index_vals.index(1):])
# Out:
# Least Risky Routes are
#  ['Maturin - Charallave', 'Colon - Panama City', 'Portland,  WA - Pasco, WA', 'Cairo - Alexandia', 'Manila - Iloilo', 'Ushuaia - Buenos Aires', 'Stockholm - Oskarshamn', 'Lisbon - Ilha do Sal - Recife', 'Bandar Abbas - Mashad', 'Amman, Jordan - Beiruit, Lebanon - Yerevan, Armenia', 'New Orleans AP - New Orleans AP', 'Lagos - Abuja - Sokoto', 'Bucharest - Vienna - Prague - Paris', 'Medical flight', 'Nairobi, Kenya  - Luskaka, Zambia', 'Berlin - Hanover - Cologne - London', 'New Orleans - Chicago', 'Pasco - Spokane', 'Detroit, MI - Louisville, KY', 'Santa Cruz - Viru', 'Berlin, Germany - Paris, France', 'Paris - Jersey , Channel Islands', 'Ogle, Guyana - Ekereku, Guyana', 'Kano - Lagos', 'Jaffna - Colombo', 'Brazzaville - Douala', 'New York City - Birmingham, AL', 'Napoli - Genoa', 'Boston, MA - Auburn, ME', 'Grand Canyon - Las Vegas', 'Colombo - Palay AFB', 'Bremen - Paris', 'Belgium - India', 'Newark, NJ - Flushing, NY', 'Constantinople - Budapest', 'Miami - Raleigh - Washington', 'Lusaka - Libreville - Dakar', 'Aden - Abu Dahbi', 'Split - Koln / London - Istanbul', 'Punta Arenas - Santiago', 'Villavicencio - Miraflores', 'Kimpo AB - Tokyo, Japan', 'Anaheim - LAX', 'Peoria, IL - St. Louis, MO', 'Nizhnevartovsk - Bugulma', 'New York City - Denver', 'Redmond - Klamath Falls - Medford', 'Seattle - Juneau', 'Honolulu - Los Angeles', 'Concord, NC - Martinsville, VA', 'Tokyo - Elmendorf AFB', 'Sidney - Brisbane', 'Skopje - Zürich', 'Douala - Lagos', 'Miami - Bogota', 'Edinburgh - Belfast', 'Griffin - Americus', 'Bogota - San Andres', 'Istanbul, Turky - Moscow, Russia', 'Athens - Bucharest', 'Boston - Newark', 'HradeKrálové - Kiev', 'Asuncion - Buenos Aires', 'Port Moresby - Tabubil', 'Hamilton, Ont, Can.- Shreveport, LA - Saltillo, Mexico', 'Goma - Kisangani - Kinshasa', 'Salvador - Guanambi', 'Tehran - Gorgan', "Lake de l'Avion - Agunish River", 'Buenos Aires - Comodoro', 'Coari - Manus', 'El Yopal - Tame', 'Spokane - Portland', 'Pittsburgh - Baltimore', 'Cairo - Alexandria', 'Baranquilla - Bogota', 'Warsaw, Poland - Bucharest, Romania', 'Atlanta - Brunswick', 'Santiago de Compostella - Madrid', 'Curacao - Miami', 'Pango Pango - Tau Island', 'Buknavu - Uvira', 'Adelaide - Whyalla', 'La Carlota - Acarigua', 'Tehran - Orumiyeh', 'Anchorage - Juneau', 'Phoenix - Las Vegas', 'Delhi - Bombay', 'Exercises', 'Puerto Montt - La Junta', 'Deauville, France - London, England', 'Parnu - Tapa', 'Florencia - Puerto Asis', 'Bartow, FL - Lake City, FL', 'Seattle - Newark', 'St. Louis, MO - Kirkville, MO', 'Pucallpa - Puerto Esperanza', 'Philadelphia, PA - Reading, PA', 'Taura - Latacunga', 'Plaa Grande - Quetzaltenango', 'Tashkent - Turtkul', 'Saigon - Da Lat', 'Miramar NAS, California - Sand Point NB, Seattle', 'Sturdee - Smithers', 'Northolt - Dublin', 'Dublin, Ireland - Addis Ababa', 'Glasgow - Dublin', 'Fairbanks, AK - Valdez, AK', 'Yinchuan - Beijing', 'Houston - Puerto Vallarta', 'Beirut - Kuwait City', 'Mexico City - New Orleans - New York City', 'Colombo - Dubai', 'Walikale - Goma', 'Fort Walton Beach, Fl - Oceana Naval Air Station, VA', 'Winnipeg - Sandy Lake', 'Sukhumi - Tbilisi', 'Wake Island - Honolulu - Oakland', 'Hiva Ou - Nuku Hiva', 'Spokane - Missoula', 'Roswell - Oakland - Guam', 'Tehran - Moscow', 'Air Show', 'Fairbanks, AK - Local', 'Maracaibo - Santa Barbara de Zulia', 'White Plains, NY - Toronto, Canada - White Plains, NY', 'Rio Hacha - Medellin', 'St. Croix - St. Kitts', 'Manaus - Brasilia', 'New Orleans - New York City', 'Miami, FL - Charleston, SC - Newark, NJ', 'Arecibo, PR - Ponce, PR', 'Eugene - Portland', 'Karlstad - Stockholm', 'Sao Paulo - Florianopolis', 'Nashville - Memphis', 'Basel - Basel', 'Tyonek, AK - Anchorage, AK', 'Jacobabad - Shamsi', 'Long Tieng, Laos - Moung Cha, Laos', 'Gisborne - Auckland', 'Burlington, WA - Friday Harbor, WA', 'Mamburao - San Jose', 'Sagwon, AK - Local', 'San Salvador - Miami', 'Cairo - Sharjah', 'Edmonton - Point Alert', 'Ozamis City - Pagadian', 'Los Angeles, CA  - Mexico City, Mexi ...

# %% [markdown]
# ## How many total fatalities occurred in year 1972?
#
# Find all rows of 1972 and then take the Fatalities sum

# %%
print("Fatalities in 1972 are {0}".format(df[df['year'] == 1972]['Fatalities'].sum()))
# Out:
# Fatalities in 1972 are 2937.0

# %% [markdown]
# ## How much percent of people survived in the entire dataset?

# %%
print("People who survived throughout are {0}".format((df['Aboard'] - df['Fatalities']).sum()))
# Out:
# People who survived throughout are 39193.0

# %% [markdown]
# ## How many planes were such that there was no registration, and yet the number of people who survived were greater than 40%?
#
# Filter only those who do not have some valid registration

# %%
df_no_regs = df[df['Registration'].isnull() == True]
num_plane_crashes_greaterthan_40 = df_no_regs[((df_no_regs['Aboard'] - df_no_regs['Fatalities'])/df_no_regs['Aboard']) > 0.4]
len(num_plane_crashes_greaterthan_40)
# Out:
# 29

# %% [markdown]
# ## Which type of aircraft is used by most operators?

# %%
print("{0} type of aircraft is the used the most.".format(df['Type'].value_counts().index[0]))
# Out:
# Douglas DC-3 type of aircraft is the used the most.

# %% [markdown]
# ## Which operator has the least & most people involved in deaths?

# %%
operator_groups = df.groupby('Operator')
max_fatalities = df['Fatalities'].max()
min_fatalities = df['Fatalities'].min()

death_dict = {}
for name, group in operator_groups:
    death_dict[name] = group['Fatalities'].sum()

## sort a dictionary by the values. .items() gives you a list containing tuples. 
## Example: [(key, value), (key, value)....]
## reverse = True meaning in descending order
## key=lambda x: x[1] --> meaning sort by the element at index 1 of every tuple
## https://docs.python.org/3/howto/sorting.html#sortinghowto

(sorted(death_dict.items(), key=lambda x: x[1], reverse=True))
#extract the max & min from this!
# Out:
# [('Aeroflot', 7156.0),
#  ('Military - U.S. Air Force', 3717.0),
#  ('Air France', 1734.0),
#  ('American Airlines', 1421.0),
#  ('Pan American World Airways', 1302.0),
#  ('Military - U.S. Army Air Forces', 1070.0),
#  ('United Air Lines', 1021.0),
#  ('AVIANCA', 941.0),
#  ('Turkish Airlines (THY)', 891.0),
#  ('Indian Airlines', 863.0),
#  ('China Airlines (Taiwan)', 847.0),
#  ('Air India', 827.0),
#  ('Military - Russian Air Force', 797.0),
#  ('Trans World Airlines', 784.0),
#  ('Military - U.S. Navy', 767.0),
#  ('Japan Air Lines', 764.0),
#  ('Korean Airlines', 713.0),
#  ('Eastern Air Lines', 710.0),
#  ('Pakistan International Airlines', 693.0),
#  ('KLM Royal Dutch Airlines', 616.0),
#  ('Pan American World Airways / KLM', 583.0),
#  ('Military - Afghan Republican Air Force', 578.0),
#  ('Garuda Indonesia Airlines', 574.0),
#  ('Northwest Orient Airlines', 531.0),
#  ('Military - Royal Air Force', 525.0),
#  ('Military -Royal Air Force', 524.0),
#  ('Ceskoslovenske Aerolinie', 516.0),
#  ('British European Airways', 512.0),
#  ('British Overseas Airways', 506.0),
#  ('Military - U.S. Army', 498.0),
#  ('Cubana de Aviacion', 486.0),
#  ('Iberia Airlines', 483.0),
#  ('Alia Royal Jordanian Airlines', 463.0),
#  ('Alitalia', 458.0),
#  ('Philippine Air Lines', 455.0),
#  ('Military - Indian Air Force', 442.0),
#  ('Air Vietnam (South Vietnam)', 434.0),
#  ('LOT Polish Airlines', 417.0),
#  ('Varig', 417.0),
#  ('Swissair', 411.0),
#  ('China National Aviation Corporation', 409.0),
#  ('EgyptAir', 406.0),
#  ('Sabena', 401.0),
#  ('Deutsche Lufthansa', 396.0),
#  ('VASP', 378.0),
#  ('Military - U.S. Marine Corps', 362.0),
#  ('Thai Airways', 358.0),
#  ('Saudi Arabian Airlines', 349.0),
#  ('Saudi Arabian Airlines / Kazastan Airlines', 349.0),
#  ('Balkan Bulgarian Airlines', 346.0),
#  ('Iran Air', 343.0),
#  ('Aerolineas Argentinas', 341.0),
#  ('United Arab Airlines', 337.0),
#  ('South African Airways', 336.0),
#  ('Linea Aeropostal Venezolana', 313.0),
#  ('Military - German Navy', 313.0),
#  ('TAM (Brazil)', 310.0),
#  ('TAME', 306.0),
#  ('Delta Air Lines', 299.0),
#  ('Military - Iranian Air Force', 295.0),
#  ('Mexicana', 290.0),
#  ('Military - Indonesian Air Force', 285.0),
#  ('Kenya Airways', 283.0),
#  ('Lloyd Aereo Boliviano', 281.0),
#  ('Aeroflot / Aeroflot', 279.0),
#  ('Dan Air Services', 278.0),
#  ("Military - IslamiRevolution's Guards Corps", 275.0),
#  ('Military - Sri Lanka Air Force', 273.0),
#  ('Merpati Nusantara Airlines', 268.0),
#  ('Military - Soviet Air Force', 268.0),
#  ('Panair do Brasil', 266.0),
#  ('Union des Transportes Aeriens', 263.0),
#  ('Air New Zealand', 261.0),
#  ('Nationair (chartered by Nigeria Airways)', 261.0),
#  ('Arrow Airways', 256.0),
#  ('United Air Lines / Trans World Airlines', 256.0),
#  ('Gulf Air', 255.0),
#  ('Ariana Afghan Airlines', 254.0),
#  ('CAAC', 251.0),
#  ('Burma Airways', 250.0),
#  ('Martinair Holland NV', 247.0),
#  ('Spantax', 247.0),
#  ('Fuerza Aérea del Peru', 244.0),
#  ('Canadian PacifiAir Lines', 234.0),
#  ('Alaska Airlines', 231.0),
#  ('Military - Argentine Air Force', 228.0),
#  ('Malev Hungarian Airlines', 227.0),
#  ('All Nippon Airways', 224.0),
#  ('Austral Lineas Aeras (Argentina)', 224.0),
#  ('Ethiopian Airlines', 223.0),
#  ('Lauda Air', 223.0),
#  ('Sudan Airways', 223.0),
#  ('Braniff Airlines', 216.0),
#  ('China Northwest Airlines', 215.0),
#  ('Cruzeiro', 213.0),
#  ('Faucett', 213.0),
#  ('Interflug', 212.0),
#  ('Trans Canada Air Lines', 212.0),
#  ('Military - Angolan Air Force', 211.0),
#  ('Far Eastern Air Transport', 208.0),
#  ('Tajikistan Airlines', 207.0),
#  ('SATENA', 201.0),
#  ('Aviaco', 200.0),
#  ('USAir', 198.0),
#  ('OlympiAirways', 195.0),
#  ('Military - Philippine Air Force', 194.0),
#  ('Tarom', 194.0),
#  ('Iraqi Airways', 193.0),
#  ('Military - Brazilian Air Force', 193.0),
#  ('Lineas Aereas Nacionales SA (Peru)', 190.0),
#  ('Military - Vietnamese Air Force', 190.0),
#  ('Alas Nacionales, leased from Birgen Air', 189.0),
#  ('Loftleidir IcelandiAirlines', 188.0),
#  ('Air Algerie', 187.0),
#  ('Capital Airlines', 187.0),
#  ('Military - Royal Saudi Air Force', 187.0),
#  ('Military - French Air Force', 186.0),
#  ('Imperial Airways', 185.0),
#  ('Military - Royal Australian Air Force', 185.0),
#  ('Inex Adria Aviopromet (Yugoslavia)', 180.0),
#  ('SAM Colombia', 178.0),
#  ('China Southern Airlines', 176.0),
#  ('Inex Adria Aviopromet / British Airways', 176.0),
#  ('Surinam Airways', 176.0),
#  ('Flying Tiger Line', 174.0),
#  ('Pulkovo Airlines', 170.0),
#  ('China Southwest Airlines', 169.0),
#  ('Mandala Airlines', 169.0),
#  ('SAETA', 169.0),
#  ('West Caribbean Airways', 168.0),
#  ('Air Inter', 167.0),
#  ('Nigeria Airways', 167.0),
#  ('Military - Nicaraguan Air Force', 165.0),
#  ('National Airlines', 164.0),
#  ('All Nippon Airways /  Japanese Air Force', 163.0),
#  ('Air Taxi', 161.0),
#  ('Military - Federal Nigerian Air Force', 158.0),
#  ('Libya Arab Airlines / Military -  Libya Air Force', 157.0),
#  ('TAAG Angola Airlines', 157.0),
#  ('LAN', 156.0),
#  ('TAM (Bolivia)', 156.0),
#  ('Gol Airlines / Private', 154.0),
#  ('Northwest Airlines', 154.0),
#  ('Spanair', 154.0),
#  ('Military - Ethiopian Air Force', 153.0),
#  ('Civil Air Transport', 152.0),
#  ('Flash Air', 148.0),
#  ('MIAT - Mongolian Airlines', 147.0),
#  ('Iran Air Tours', 146.0),
#  ('Lufthansa', 146.0),
#  ('Aviateca', 145.0),
#  ('REAL', 145.0),
#  ('Vladivostokavia', 145.0),
#  ('Independent Air Inc.', 144.0),
#  ('Trans Service Airlift', 144.0),
#  ('Aviation Development Corporation', 143.0),
#  ('Trans Continental and Western Air', 142.0),
#  ('Itavia', 141.0),
#  ('LANSA', 141.0),
#  ('Sobelair SA (Belgium)', 141.0),
#  ('Vnokovo Airlines', 141.0),
#  ('Cathay PacifiAirways', 140.0),
#  ('Middle East Airlines', 140.0),
#  ('Union des Transports Aeriens de Guinee', 140.0),
#  ('Air Canada', 138.0),
#  ('PacifiSouthwest Airlines / Private', 137.0),
#  ('Southern Airways', 137.0),
#  ('Sterling Airways', 137.0),
#  ('JAT Yugoslav Airlines', 136.0),
#  ('Western Airlines', 135.0),
#  ('Malaysia Airlines', 134.0),
#  ('Transair Georgia Airlines', 134.0),
#  ('Iran Air Tours  /  Military - Iranian Air Force', 133.0),
#  ('Air Philippines', 131.0),
#  ('British Eagle International Airlines', 131.0),
#  ('TAP (Air Portugal)', 131.0),
#  ('TAN', 130.0),
#  ('Ukrainian Cargo Airlines -  Congolese Army Charter', 129.0),
#  ('Air China', 128.0),
#  ('China Southwest Airlines / Xiamen Airlines', 128.0),
#  ('Iran National Airlines', 128.0),
#  ('Sibir (S7)', 128.0),
#  ('Taxi Aereo el Venado', 128.0),
#  ('Globe Air', 126.0),
#  ('Military - Chinese Air Force', 125.0),
#  ('Baikal Air', 124.0),
#  ('China Northern Airlines', 124.0),
#  ('Sibir Airlines', 124.0),
#  ('Compania de Aviacion Faucett SA (Peru)', 123.0),
#  ('Private', 123.0),
#  ('Helios Airways', 121.0),
#  ('Military - Republiof South Korea Air Force', 121.0),
#  ('Military Soviet  Air Force - Aeroflot', 120.0),
#  ('British Midland Airways', 119.0),
#  ('Bellview Airlines', 117.0),
#  ('Air America', 116.0),
#  ('Aviaimpex (Macedonia)', 116.0),
#  ('Scandinavian Airlines (SAS)', 116.0),
#  ('Aero Transporti Italiani', 114.0),
#  ('Scandinavian Airlines (SAS) / Private', 114.0),
#  ('Armavia', 113.0),
#  ('Caledonian Airways', 111.0),
#  ('Aigle Azur', 110.0),
#  ('Libya Arab Airlines', 110.0),
#  ('ValuJet', 110.0),
#  ('Military - IslamiRepubliof Iran Air Force', 109.0),
#  ('China General Aviation Corporation', 108.0),
#  ('Invicta International Airlines (UK)', 108.0),
#  ('Sosoliso Airlines', 108.0),
#  ('Linee Aeree Italiane', 107.0),
#  ('Transocean Air Lines', 106.0),
#  ('Royal Air Maroc', 105.0),
#  ('Cebu PacifiAir', 104.0),
#  ('Kam Air', 104.0),
#  ('Military - Royal Thai Air Force', 104.0),
#  ('SilkAir', 104.0),
#  ('Adam Air', 102.0),
#  ('Compania Dominicana de Aviacion', 102.0),
#  ('Military - Pakistan Air Force', 102.0),
#  ('Royal Nepal Airlines', 102.0),
#  ('Aerovias de Guatemala SA', 100.0),
#  ('Britannia Airways', 98.0),
#  ('Far East Aviation', 98.0),
#  ('Pennsylvania Central Airlines', 98.0),
#  ('ADC Airlines', 97.0),
#  ('Air Rhodesia', 97.0),
#  ('British South American Airways', 95.0),
#  ('TACA', 95.0),
#  ('Vietnam Airlines', 95.0),
#  ('Aerolineas TAO', 94.0),
#  ('Avensa', 93.0),
#  ('Iberia Airlines / Aviaco', 93.0),
#  ('Military - Venezuelan Air Force', 93.0),
#  ('Military - Republiof China Air Force', 92.0),
#  ('China Eastern Airlines', 91.0),
#  ('Military - Sudan Air Force', 91.0),
#  ('Military - Sudanese Air Force', 91.0),
#  ('Northeast Airlines', 91.0),
#  ('American Eagle', 90.0),
#  ('One-Two-Go Airlines', 90.0),
#  ('Military - Royal Canadian Air Force', 89.0),
#  ('Qantas', 89.0),
#  ('Air Ferry Ltd', 88.0),
#  ('World Airways', 88.0),
#  ('Aer Lingus', 87.0),
#  ('Allegheny Airlines', 87.0),
#  ('Military - Azerbaijan Air Force', 87.0),
#  ('Military - Zairean Air Force', 87.0),
#  ('Comair', 86.0),
#  ('Piedmont Airlines / Private', 86.0),
#  ('TABA', 86.0),
#  ('Maritime Central Airways', 85.0),
#  ('Military - Belgian Air Force', 85.0),
#  ('Paradise Airlines', 85.0),
#  ('Singapore Airlines', 85.0),
#  ('Somali Airlines', 85.0),
#  ('Military - Honduran Air Force', 84.0),
#  ('Venezolana Internacional de Aviacion', 84.0),
#  ('Allegheny Airlines / Forth Corporation', 83.0),
#  ('American Flyers Airline', 83.0),
#  ('Continental Airlines', 83.0),
#  ('Military - Georgian Air Force', 83.0),
#  ('Palair Macedonian', 83.0),
#  ('President Airlines', 83.0),
#  ('Transportno Aviatsionno Bulgaro-Soviet Obshchestvo', 82.0),
#  ('Air Mauritanie', 80.0),
#  ('Fairflight Ltd.', 80.0),
#  ('Fuerza Aérea Colombiana', 80.0),
#  ('Aeropesca Colombia', 79.0),
#  ('Compania Mexicana de Aviacion', 79.0),
#  ('Military - U.S. Air Force / Military - U.S. Air Force', 79.0),
#  ('Australian National Airways', 78.0),
#  ('Aviogenex (Yugoslavia)', 78.0),
#  ('Cameroon Airlines', 78.0),
#  ('Misrair', 78.0),
#  ('Wenela Air Services', 78.0),
#  ('Aerovias Venezolanas SA (Venezuela)', 77.0),
#  ('Military - Russian Air Force / Military - Russian Air Force', 77.0),
#  ('Aeroflot / Soviet Air Force', 76.0),
#  ('Aeronaves de Mexico', 76.0),
#  ('Aeroperu', 76.0),
#  ('Bakhtar Afghan Airlines', 76.0),
#  ('Hang Khong (Vietnam)', 76.0),
#  ('Myanmar Airways', 76.0),
#  ('Aeroflot Russian International Airways', 75.0),
#  ('Aeromexico', 75.0),
#  ('Inex Adria Aviopromet', 75.0),
#  ('Military - Royal Belgian Air Force', 75.0),
#  ('Military - Union of Burma Air Force', 75.0),
#  ('Ukranian-Mediterranean Airlines', 75.0),
#  ('Air Florida', 74.0),
#  ('Azerbaijani Airlines', 74.0),
#  ('EAS Airlines (Executive Airline Services)', 74.0),
#  ('Fuerza Aérea Argentina', 73.0),
#  ('Military - Chilean Air Force', 73.0),
#  ('Military - Israel Air Force /Military -  Israel Air Force', 73.0),
#  ('Military - Egyptian Air Force', 72.0),
#  ('Bashkirian Airlines / DHL Worldwide Express', 71.0),
#  ('Mohawk Airlines', 71.0),
#  ('SATA', 71.0),
#  ('Aerosweet Airlines (LVOV)', 70.0),
#  ('Galaxy Airlines', 70.0),
#  ('Military - Mozambique Air Force', 70.0),
#  ('Transportes Aereos del Caribe', 70.0),
#  ('AREA', 69.0),
#  ('Ansett ANA', 69.0),
#  ('El Al', 69.0),
#  ('Military - Japan Maritime Self Defense Force', 69.0),
#  ('Asiana Airlines', 68.0),
#  ('Itek Air', 68.0),
#  ('Lineas Aereas de Espana/Spantax SA Transportes', 68.0),
#  ('Toa DomestiAirline (Japan)', 68.0),
#  ('Aeromexico / Private', 67.0),
#  ('Air Madagascar', 67.0),
#  ('Alyemda', 67.0),
#  ('Military - German Army', 67.0),
#  ('Military - Peruvian Air Force', 67.0),
#  ('Pelita Air Service', 67.0),
#  ('Transbrasil', 67.0),
#  ('Iran Asseman Airlines', 66.0),
#  ('Military - Italian Air Force', 66.0),
#  ('Air Nautic', 65.0),
#  ('LAPA, Lineas Aereas Privadas Argentinas', 64.0),
#  ('Piedmont Airlines', 64.0),
#  ('East African Airways', 63.0),
#  ('Miami Airlines', 63.0),
#  ('Military - HelleniAir Force', 63.0),
#  ("Wideroe's Flyveselksap", 63.0),
#  ('Military - Colombian Air Force', 62.0),
#  ('Air Manila', 61.0),
#  ('REAL / Military - U.S. Navy', 61.0),
#  ('Aerolineas Nacionales', 60.0),
#  ('Aerovias Brasil', 60.0),
#  ('Ecuatair', 60.0),
#  ('Royal Air Lao', 60.0),
#  ('Transporturile Aeriene Romane (TAROM)', 60.0),
#  ('Military - Zambian Air Force', 59.0),
#  ('PacifiWestern Airlines', 59.0),
#  ('AB Aerotransport', 58.0),
#  ('Wuhan Airlines', 58.0),
#  ('Air Mali', 57.0),
#  ('Asa Pesada', 57.0),
#  ('Atlasjet Airlines', 57.0),
#  ('Military - French Naval Aviation', 57.0),
#  ('Military - Unified Yemen Air Force', 57.0),
#  ('Pan African Airlines', 57.0),
#  ('Air Afrique', 56.0),
#  ('Military - Bolivian Air Force', 56.0),
#  ('Military - Royal Nepalese Air Force', 56.0),
#  ('New Zealand National Airways', 56.0),
#  ('Scottish Airlines', 56.0),
#  ('Talair', 56.0),
#  ('Bali International Air Service', 55.0),
#  ('British Airtours', 55.0),
#  ('Eastern Air Lines / Military - Bolivian Air Force', 55.0),
#  ('Indian Airlines/Alliance Airlines', 55.0),
#  ('Lionair', 55.0),
#  ('Partnair', 55.0),
#  ('Bouraq Indonesia Airlines', 54.0),
#  ('Military - Israel Air Force', 54.0),
#  ('Norwegian Airlines', 54.0),
#  ('Federal Airlines', 53.0),
#  ('Formosa Airlines', 53.0),
#  ('Military - Polish Air Force', 53.0),
#  ('Strato Freight', 53.0),
#  ('T.A. Intercontinentaux (France)', 53.0),
#  ('Aeropostale', 52.0),
#  ('Curtiss-Reid Flying Services Ltd. (Canada)', 52.0),
#  ('Military - French Navy', 52.0),
#  ('Military - South African Air Force', 52.0),
#  ('Military - Soviet Navy', 52.0),
#  ('Transport Aerien Intercontinentaux (France)', 52.0),
#  ('Intercontinental de Aviacion', 51.0),
#  ('Military - Mauritanian Air Force', 51.0),
#  ('Central African Airways', 50.0),
#  ("Gor'ky Eskadril'ya", 50.0),
#  ('Hughes Airwest  / Military - US Marine Air Corps', 50.0),
#  ('Military - Dostum-Galboddin Militia', 50.0),
#  ('Military - Imperial Iranian Air Force', 50.0),
#  ('Stavropol Airlines', 50.0),
#  ('Bangladesh Biman', 49.0),
#  ('Continental Connection/Colgan Air', 49.0),
#  ('Military - Ecuadorean Air Force', 49.0),
#  ('Military - Iranian Revolutionary Guard Corps Air Force', 49.0),
#  ('Petroleum Helicopter', 49.0),
#  ('Romanian Banat Air', 49.0),
#  ('United Air Lines / Military - U.S. Air Force', 49.0),
#  ('Ala Littoria', 48.0),
#  ('Military - British Air Ministry', 48.0),
#  ('Military - Congolese Air Force', 48.0),
#  ('Military - U.S. Marine Corps/Military - U.S. Marine Corps', 48.0),
#  ('Sociedad Aeronautica Medellin', 48.0),
#  ('Air  Mali', 47.0),
#  ('Bulair TABSO', 47.0),
#  ('COPA (Panama)', 47.0),
#  ('Finnair', 47.0),
#  ('Fuerza Area Angolaise', 47.0),
#  ('LAV - Linea Aeropostal Venezolana', 47.0),
#  ('Military - U.S.  Air Force / Military - U.S. Navy', 47.0),
#  ('Union of Burma Airways', 47.0),
#  ('Aeronor Chile', 46.0),
#  ('Avio Linee Italiane', 46.0),
#  ('Dirgantara Air Services', 46.0),
#  ('Loide Aereo Nacional', 46.0),
#  ('Military - Kenyan Air Force', 46.0),
#  ('Military - Royal Airship Works', 46.0),
#  ('Military - Venezuelan Navy', 46.0),
#  ('PacifiSouthwest Airlines', 46.0),
#  ('Santa Barbara Airlines', 46.0),
#  ('T.A. Intercontinentaux', 46.0),
#  ('TANS Airlines', 46.0),
#  ('Aden Airways', 45.0),
#  ('Aerolineas Centrales de Colombia', 45.0),
#  ('British International Helicopters', 45.0),
#  ('PacifiAir Lines', 45.0),
#  ('Vayudoot', 45.0),
#  ('Wigmo', 45.0),
#  ('Aca-Ancargo', 44.0),
#  ('Aerolineas Condor', 44.0),
#  ('Aeromist-Kharkiv', 44.0),
#  ('Los Angeles Airways', 44.0),
#  ('Military - Turkish Air Force', 44.0),
#  ('Military - U.S. Army / Military - U.S. Army', 44.0),
#  ('Military - Uruguayan Air Force', 44.0),
#  ('Taxader Airlines', 44.0),
#  ('Tigres Voladores', 44.0),
#  ('Air Laos', 43.0),
#  ('Aquilla Airways', 43.0),
#  ('Cubana de Aviacion / Military -  US Navy', 43.0),
#  ('Kalinga Airlines', 43.0),
#  ('Kish Airlines', 43.0),
#  ('TAM Lineas Aéreas Regional', 43.0),
#  ('Braathens', 42.0),
#  ('Military - Peruvian Naval Aviation', 42.0),
#  ('Military - Slovak Air Force', 42.0),
#  ('Military - U. S. Navy', 42.0),
#  ('Pan African Air Charter', 42.0),
#  ('Saha Airline Services', 42.0),
#  ('Shanxi Airlines', 42.0),
#  ('Congo Airline', 41.0),
#  ('Indian National Airlines', 41.0),
#  ('Societe Aerienne du Littoral', 41.0),
#  ('Tartarstan Airlines', 41.0),
#  ('Volga-Avia Express', 41.0),
#  ('ACES Colombia', 40.0),
#  ('AVISPA', 40.0),
#  ('Associated Air Transport', 40.0),
#  ('Eagle Aviation', 40.0),
#  ('Icelandair', 40.0),
#  ('Military - Deutsche Luftwaffe', 40.0),
#  ('TANS Peru', 40.0),
#  ('US Aerial Mail Service', 40.0),
#  ('Wien Consolidated Airlines', 40.0),
#  ('American Overseas Airlines', 39.0),
#  ('Cambodia Air', 39.0),
#  ('Cunard Eagle Airways', 39.0),
#  ('Devlet Hava Yollari', 39.0),
#  ('Lancashire Aircraft Corporation (Skyways)', 39.0),
#  ('Scibe Airlift Cargo Zaire', 39.0),
#  ('Societe Alpes Provence', 39.0),
#  ('Trans Australia Airlines', 39.0),
#  ('Uzbekistan Airways', 39.0),
#  ('AVIANCA / AVIANCA', 38.0),
#  ('AtlantiSoutheast Airlines', 38.0),
#  ('Bangkok Airways', 38.0),
#  ('Lake Central Airlines', 38.0),
#  ('Ozark Air Lines', 38.0),
#  ('Paraense Transportes Aereos', 38.0),
#  ('Paukn Air', 38.0),
#  ('Air Sinai', 37.0),
#  ('Airfast Services', 37.0),
#  ('Force Area Populaire de Angola', 37.0),
#  ('Lloyd Aereo Colombiano', 37.0),
#  ('Military - El Salvador Air Force', 37.0),
#  ('Military - Forces Militaires Françaises', 37.0),
#  ('Military - Portuguese Air Force', 37.0),
#  ('Queen Charlotte Airlines', 37.0),
#  ('Sakha Airlines', 37.0),
#  ('ARTOP Aerotopografica LDA', 36.0),
#  ('Empresa Aviacion del Pacifico', 36.0),
#  ('Kuban Airlines', 36.0),
#  ('Ladeco', 36.0),
#  ('Military - Force Aérienne Zaïroise', 36.0),
#  ('Military - Mexican Air Force', 36.0),
#  ('Military - U. S. Air Force', 36.0),
#  ('Milne Bay Air', 36.0),
#  ('Missionary Aviation Fellowship', 36.0),
#  ('New Tribes Mission', 36.0),
#  ('SANSA', 36.0),
#  ('Sierra PacifiAirlines', 36.0),
#  ('Syndicato Condor', 36.0),
#  ('Trans Canada Air Lines / RCAF', 36.0),
#  ('United Airways', 36.0),
#  ('Deutsche Zeppelin Reederei', 35.0),
#  ('Military - Royal Lao Air Force', 35.0),
#  ('Military - West German Air Force', 35.0),
#  ('Mineral County Airlines', 35.0),
#  ('Polynesian Airlines', 35.0),
#  ('Silver City Airways', 35.0),
#  ('Standard Airlines', 35.0),
#  ('Aero Holland', 34.0),
#  ('Aerocaribbean - Charter', 34.0),
#  ('American Airways', 34.0),
#  ('Crossair', 34.0),
#  ('Derby Aviation', 34.0),
#  ('Florida Commuter Airlines', 34.0),
#  ('Garuda  Indonesia Airlines / Garuda Indonesia Airlines', 34.0),
#  ('Government of Mozambique', 34.0),
#  ('Lineas Areas Venezolanas', 34.0),
#  ('Military - Madagascar Air Force', 34.0),
#  ('Military - U.S. Army Air Service', 34.0),
#  ('Moldovan Aeriantur-M Air Cargo', 34.0),
#  ('OlympiAviation', 34.0),
#  ('Shell Co of Ecuador', 34.0),
#  ('USAir / Skywest Airlilnes', 34.0),
#  ('Uzbek Civil Aviation Administration', 34.0),
#  ('Yacimientos Petroliferos Fiscales', 34.0),
#  ('Aeroflot /Military - Russian', 33.0),
#  ('Air Transport', 33.0),
#  ('Commercial Air Taxi', 33.0),
#  ('Hunting Air Travel', 33.0),
#  ('Las Vegas Airlines', 33.0),
#  ('Military - Luftwaffe / Military - USAF', 33.0),
#  ('Military - U.S. Navy / Military - U.S. Navy', 33.0),
#  ('Military - United States Army Air Force', 33.0),
#  ('Pan American Airways', 33.0),
#  ('Rico Linhas Aereas', 33.0),
#  ('Servicios Aereos Nacionales Airways', 33.0),
#  ('Uganda Airlines', 33.0),
#  ('Airborne Transport', 32.0),
#  ('Airline Transport Carriers', 32.0),
#  ('Dutch Dakota Association', 32.0),
#  ('Expresso Aéreo', 32.0),
#  ('Pan ArctiOil', 32.0),
#  ('Prinair', 32.0),
#  ('Transair', 32.0),
#  ('Aeroflot / Military - Russian Air Force', 31.0),
#  ('Aeronica', 31.0),
#  ('Austrian Airlines', 31.0),
#  ('Azerbaijan Airlines', 31.0),
#  ('DTA Angola Airlines', 31.0),
#  ('Deccan Airways', 31.0),
#  ('Dominicana', 31.0),
#  ('Linjefyg', 31.0),
#  ('Midwest Express', 31.0),
#  ('Military - U.S. Marines', 31.0),
#  ('Rousseau Aviaiton', 31.0),
#  ('ANDESA', 30.0),
#  ('Aeroperlas', 30.0),
#  ('COHATA', 30.0),
#  ('Charter, Golden Eagle Aviation Inc.', 30.0),
#  ('Faraz Qeshm Airlines', 30.0),
#  ('Gambcrest', 30.0),
#  ('MMM Aero Services', 30.0),
#  ('Sempati Air', 30.0),
#  ('TAESA', 30.0),
#  ('Yeti Airlines', 30.0),
#  ('Bonanza Airlines', 29.0),
#  ('LARES', 29.0),
#  ('Lineas Aereas de Angola', 29.0),
#  ('Military - Cuban Air Force', 29.0),
#  ('National Jet Services Inc.,  (Air Indiana)', 29.0),
#  ('North Continental Airlines (Robin Airlines)', 29.0),
#  ('Taiwan Airlines', 29.0),
#  ('Uruguayan Air Force - TAMU', 29.0),
#  ('Aerolineas Litoral Argentina', 28.0),
#  ('Air Guadeloupe', 28.0),
#  ('Airlink', 28.0),
#  ('Cheremshanka Airlines', 28.0),
#  ('Fuerza Aérea Nicaragua', 28.0),
#  ('Military - Salvadoran Air Force', 28.0),
#  ('Military - U.S. Air Force / U.S. Air Force', 28.0),
#  ('Military U.S. Navy / Military - U.S. Navy', 28.0),
#  ('Peninsular', 28.0),
#  ('Regional Airlines', 28.0),
#  ('Syrian Airways', 28.0),
#  ('Taxi Aereo de Santander', 28.0),
#  ('Trans World Airlines / Private', 28.0),
#  ('Westair Transport', 28.0),
#  ('AIRES Colombia', 27.0),
#  ('Aero O-Y', 27.0),
#  ('Bazair', 27.0),
#  ('Charter - IRS Aero', 27.0),
#  ('Charter - Maniema Union (owner Victoria Air)', 27.0),
#  ('ClassiWings', 27.0),
#  ('Frigorifico Cooperativo Los Andes', 27.0),
#  ('Lebanese International Airways', 27.0),
#  ('Lineas Aéreas Nacionales', 27.0),
#  ('MAP', 27.0),
#  ('Military - Nigerian Air Force', 27.0),
#  ('Military - Royal Indian Air Force', 27.0),
#  ('Military - U.S. Navy / Military -  U.S. Navy', 27.0),
#  ('North Central Airlines', 27.0),
#  ('Staer Air', 27.0),
#  ('Viking Air Transport', 27.0),
#  ('British United Airways', 26.0),
#  ('Cie Air Transport', 26.0),
#  ('Continental Charters', 26.0),
#  ('Cruzeiro Do Sud', 26.0),
#  ('Douglas Airways', 26.0),
#  ('Lao Aviation', 26.0),
#  ('Lion Air', 26.0),
#  ('MaRobertson-Miller Airlines', 26.0),
#  ('Military - Colombian Army', 26.0),
#  ("Military - Lao People's Liberation Army Air Force", 26.0),
#  ('Military - Royal Jordanian Air Force', 26.0),
#  ('Military - U.S. Army / Military U.S. Army', 26.0),
#  ('Pakair', 26.0),
#  ('Petroproducción', 26.0),
#  ('Rimouski Airlines', 26.0),
#  ('Ryan Air Services', 26.0),
#  ('Servicios Aéreos Especiales', 26.0),
#  ('Solomon Islands Airlines', 26.0),
#  ('VASP / Private', 26.0),
#  ('Aerovias Guest', 25.0),
#  ('Air Senegal', 25.0),
#  ('BOAC', 25.0),
#  ('Flugefelag', 25.0),
#  ('Grand Canyon Airlines / Helitech', 25.0),
#  ('Military - Guatemalan Air Force', 25.0),
#  ('Military - Royal British Navy', 25.0),
#  ('Military - U.S. Air Force / Military -  U.S. Army', 25.0),
#  ('Military - U.S. Army Air Forces / Military - U.S. Army Air Forces', 25.0),
#  ('Prestige Airlines (Cargo) Charter', 25.0),
#  ('Resort Airlines', 25.0),
#  ('SAMSA', 25.0),
#  ('VOTEC', 25.0),
#  ('West Coast Airlines', 25.0),
#  ('Aerotaxi Manaus', 24.0),
#  ('Air Ontario', 24.0),
#  ('Bristow Helicopters', 24.0),
#  ('Chicago Southern Airlines', 24.0),
#  ('China Air Lines', 24.0),
#  ('Georgian Air', 24.0),
#  ('Grands Express Aeriens', 24.0),
#  ('Military - Centrafricain Airlines', 24.0),
#  ("Military - People's Army/ Military - Peoples Air Force", 24.0),
#  ('Military - United States Navy', 24.0),
#  ('Military - Venezuelan Army', 24.0),
#  ('PacifiOverseas Airways', 24.0),
#  ('Permaviatrans', 24.0),
#  ('Rutaca Airlines', 24.0),
#  ('Sasco Air Lines', 24.0),
#  ('Servicios Aereos Nacionales', 24.0),
#  ('Si Fly - U.N. charter', 24.0),
#  ('Southern Sudan Air Connection', 24.0),
#  ('Thai International', 24.0),
#  ('Transcontinental', 24.0),
#  ('Transportes Areos Nacionales', 24.0),
#  ('United Nations -  UTair Charter', 24.0),
#  ('Aerovias Contreras', 23.0),
#  ('Air Congo', 23.0),
#  ('Antillian Airlines', 23.0),
#  ('CAAK', 23.0),
#  ('CTA LanguedoRoussillon', 23.0),
#  ('Deruluft', 23.0),
#  ('Military - Peruvian Army Aviation', 23.0),
#  ('Military - Royal HelleniAir Force', 23.0),
#  ('Pan American Grace Airways', 23.0),
#  ('Rico Taxi Aéreo', 23.0),
#  ('SAESA', 23.0),
#  ('SceniAir Tours', 23.0),
#  ('Transafrik', 23.0),
#  ('Transport Arien Transregional', 23.0),
#  ('ADES Colombia', 22.0),
#  ('Aero Taxis Equatorianos', 22.0),
#  ('Aerovias Urraca', 22.0),
#  ('Air Lanka', 22.0),
#  ('ArctiPacific', 22.0),
#  ('Avisto', 22.0),
#  ('Central Air Transport', 22.0),
#  ('Central Mountain Air Services', 22.0),
#  ('Europe Aero Service EAS', 22.0),
#  ('Latecoere Airlines', 22.0),
#  ('Lineas Areas Unidas', 22.0),
#  ('Lineas Aéreas Costarricenses  LACSA', 22.0),
#  ('Military - Spanish Air Force.', 22.0),
#  ('PMT Air', 22.0),
#  ('Pan International', 22.0),
#  ('Regina Cargo Airlines', 22.0),
#  ('Sabah Air', 22.0),
#  ('Skyline Sweden', 22.0),
#  ('Southwest Airways', 22.0),
#  ('TAM (Peru)', 22.0),
#  ('TMK Air Commuter', 22.0),
#  ('Tech - Aeronautical Explotiation', 22.0),
#  ('Trigana Air Service', 22.0),
#  ('Aerocalifornia', 21.0),
#  ('Aerolift Philippines', 21.0),
#  ('Aerolineas Abaroa', 21.0),
#  ('Africa One Congo', 21.0),
#  ('Air Littoral', 21.0),
#  ('Air taxi', 21.0),
#  ('Alas Chiricanas', 21.0),
#  ('FAMA (Argentina)', 21.0),
#  ("L'Armée de L'Air", 21.0),
#  ('Military - Florida Army National Guard', 21.0),
#  ('Military - Força Aérea Portuguesa', 21.0),
#  ('NFD - Nurnberger Flugdienst', 21.0),
#  ('Pakistan Airways', 21.0),
#  ('Paramount Airlilnes', 21.0),
#  ('Quebecair', 21.0),
#  ('Sadia', 21.0),
#  ('Sahsa Airlines', 21.0),
#  ('Trans-Luxury Airlines', 21.0),
#  ('Tropical Airways', 21.0),
#  ('US Air Express/Air Midwest', 21.0),
#  ('Aerocaribe', 20.0),
#  ('Agencia Interamericana de Aviada', 20.0),
#  ('Air Moorea', 20.0),
#  ('Air St. Martin', 20.0),
#  ('Aloha Island Air', 20.0),
#  ('Avicsa', 20.0),
#  ('British Airways Helicopters', 20.0),
#  ("Chalk's Ocean Airways", 20.0),
#  ('Downeast Airlines', 20.0),
#  ('F.R. de la Direccion General de Ados', 20.0),
#  ('Fuji Airlines', 20.0),
#  ('Jamair', 20.0),
#  ('Khalatyrka', 20.0),
#  ('Krasnoyarskie Avialinii', 20.0),
#  ('Lanica', 20.0),
#  ('Lineas Aereas', 20.0),
#  ('Lineas Aéreas la Urraca', 20.0),
#  ('Luxair', 20.0),
#  ('Mililtary - Soviet Air Force', 20.0),
#  ('Military -  (2) U.S. Army Air Forces', 20.0),
#  ('Military - Angolan Armed Forces', 20.0),
#  ('Military - Chilian Air Force', 20.0),
#  ('Military - Colombian government', 20.0),
#  ('Military - Força Aérea Brasileira', 20.0),
#  ('Military - Israel  Air Force', 20.0),
#  ('Military - Royal Netherlands East Indies Air Force', 20.0),
#  ('Military - Taliban Militia', 20.0),
#  ('Naftogaz', 20.0),
#  ('Philippine Aerotransport', 20.0),
#  ('Trafik-Turist-Transportflyg', 20.0),
#  ('Trans Mediterranean Airways', 20.0),
#  ('Transporte Aereo Federal', 20.0),
#  ('Aero Ferinco Charter', 19.0),
#  ('Air Caraibes', 19.0),
#  ('Austin Airways', 19.0),
#  ('Blue Wing Airlines', 19.0),
#  ('British Commonwealth PacifiAirlines', 19.0),
#  ('Charter -Federal Electricity Commission', 19.0),
#  ('Everest Air', 19.0),
#  ('Executive Airlines', 19.0),
#  ('Fujita Koku Kabushki Kai', 19.0),
#  ('Gabon Express', 19.0),
#  ('Haïti Air Inter', 19.0),
#  ('Laoag International Airlines', 19.0),
#  ('Military - Royal Norwegian Air Force', 19.0),
#  ('Military - U.S. Army Air Force', 19.0),
#  ('Necon Air', 19.0),
#  ('SELVA', 19.0),
#  ('TAC Colombia', 19.0),
#  ('Team Air', 19.0),
#  ('Transportes Aereos Nacionales', 19.0),
#  ('U. S. Air Force', 19.0),
#  ('VOTEC / VOTEC', 19.0),
#  ('ALFA', 18.0),
#  ('Adventure Airlines', 18.0),
#  ('Aeropeca', 18.0),
#  ('Aerovias Rojas', 18.0),
#  ('Air Logistics', 18.0),
#  ('Air Outremer', 18.0),
#  ('Boeing Aircraft Company', 18.0),
#  ('Coastal Air Lines', 18.0),
#  ('Express Airlines - Northwest Airlink', 18.0),
#  ('GT Air', 18.0),
#  ('Helikopter Service', 18.0),
#  ('Holyman Airways', 18.0),
#  ('Jetwingsco Inc. - Private Charter', 18.0),
#  ('Lineas Areas del Centro', 18.0),
#  ('Lineas Aéreas La Urraca', 18.0),
#  ('Loide Aéreo Nacional', 18.0),
#  ('Lumbini Airways', 18.0),
#  ('MaRoberston-Miller Airlines', 18.0),
#  ('Manchurian Air Lines', 18.0),
#  ('Merpati Nasantara Airlines', 18.0),
#  ('Military - Australian Army Aviation', 18.0),
#  ('Military - Royal Lesotho Defence Force', 18.0),
#  ('Military - Russian', 18.0),
#  ('Military - Russian, cargo', 18.0),
#  ('Military - U.S. Air Force/Military - U.S. Air Force', 18.0),
#  ('Military - Vietnamese Air Force / Military - U.S. Army', 18.0),
#  ('Nacional de Aviacion', 18.0),
#  ('Nile Delta Air Services', 18.0),
#  ('Pathet Lao Airlines', 18.0),
#  ('Queensland Airlines', 18.0),
#  ('Saudi Arabian Royal Flight', 18.0),
#  ('Shangri La Air', 18.0),
#  ('TABSO', 18.0),
#  ('TACV-Cabo Verde Airlines', 18.0),
#  ('Taiwan Aviation', 18.0),
#  ('Transaven', 18.0),
#  ('Aerocondor de Colombia', 17.0),
#  ('Air Carriers Express Services Inc', 17.0),
#  ('Air Fiji', 17.0),
#  ('Air Ivorie', 17.0),
#  ('Air Orient', 17.0),
#  ('Air Serv Internatiional/CemAir', 17.0),
#  ('Air Union', 17.0),
#  ('Airfast Indonesia', 17.0),
#  ('Asian Spirit', 17.0),
#  ('CIDNA', 17.0),
#  ('Charter - Aerotaxi', 17.0),
#  ('Colonial Western Airlines', 17.0),
#  ('Columbia PacifiAirlines', 17.0),
#  ('Commercial Airways (Comair)', 17.0),
#  ('Cougar Helicopters', 17.0),
#  ('Cubana de Aviacon', 17.0),
#  ('Magistralnye Avialinii', 17.0),
#  ('Middle East Airlines / Military - Turkish Air ForceC-47', 17.0),
#  ('Military - Burma Air Force', 17.0),
#  ('Military - Greek Army', 17.0),
#  ('Military - Russian Navy', 17.0),
#  ('Military - Zimbabwe Air Force', 17.0),
#  ('NLM (Nederlandse Luchtvaart Maatschappij)', 17.0),
#  ('Orient Airways', 17.0),
#  ('PacifiAlaska Air Freight', 17.0),
#  ('Pan American Grace Airlines', 17.0),
#  ('Paraense Transportes Aéreos', 17.0),
#  ('SceniAirlines', 17.0),
#  ('Servicio Aereo Columbiano / SCADTA', 17.0),
#  ('Shelter Cove Sea Park', 17.0),
#  ('Société Aérienne de Tr. Tropicaux', 17.0),
#  ('Tracep', 17.0),
#  ('Union Aeromaritime de Transport', 17.0),
#  ('Wings West Airlines / Private', 17.0),
#  ('Yakutavia', 17.0),
#  ('ALADA', 16.0),
#  ('Aerolift', 16.0),
#  ('Aeroservicios Empresariales de Durango', 16.0),
#  ('Aerosucre Colombia', 16.0),
#  ('Air Ocean', 16.0),
#  ('Air Reconnaissance Unit of Liberia', 16.0),
#  ('Avion Airways', 16.0),
#  ('Bond Offshore Helicopters', 16.0),
#  ('CSA Czech Airlines', 16.0),
#  ('Condor Flugdienst', 16.0),
#  ('Eastern Air Lines / Military - USN', 16.0),
#  ('Ejercito del Aire', 16.0),
#  ('Fuerza Aérea Panamena', 16.0),
#  ('Grand Canyon Airlines', 16.0),
#  ('Guardia Nacional de Venezuela', 16.0),
#  ('Gulf Aviation (Kalinga Airways)', 16.0),
#  ('Harka Air Services', 16.0),
#  ('Heliandes', 16.0),
#  ('Holmstoem Air', 16.0),
#  ('KNILM', 16.0),
#  ('La Costena', 16.0),
#  ('Lineas Aereas del Estado', 16.0),
#  ('Maddux Airlines', 16.0),
#  ('Mid Continent Airlines', 16.0),
#  ('Military - Corrieri Aerei Militari', 16.0),
#  ("Military - People's Liberation Army", 16.0),
#  ('Military - Spanish Air Force', 16.0),
#  ('Military - U.S. Air Force / Military -  U.S. Air Force', 16.0),
#  ('Military - U.S. Navy / NASA', 16.0),
#  ('Nordeste Linhas Aéreas', 16.0),
#  ('Pan Malaysian Air Transport', 16.0),
#  ('Perris Valley Aviation', 16.0),
#  ('RRC Air Service', 16.0),
#  ('Reeve Aleutian Airlines', 16.0),
#  ('Robinson Airlines', 16.0),
#  ('SFC Vietnam - Charter - Full Account', 16.0),
#  ('Siamese Airways', 16.0),
#  ('Slick Airways', 16.0),
#  ('Sociedade de Aviacao Ligeira Charter', 16.0),
#  ('Societe France Hydro', 16.0),
#  ('Societe Indochinoise de Raviteillement', 16.0),
#  ('Southwest Air', 16.0),
#  ('Transported Areos Profesionales - TAPSA', 16.0),
#  ('Tuninter', 16.0),
#  ('United Nations Organization', 16.0),
#  ('Universal Airlines', 16.0),
#  ('Vanair', 16.0),
#  ('Vehu Akat', 16.0),
#  ('Vostok Aviakompania', 16.0),
#  ('VoteTaxi Aéreo', 16.0),
#  ('Aero-Tropics', 15.0),
#  ('Aerochasqui', 15.0),
#  ('Air Comores', 15.0),
#  ('Air Guinee', 15.0),
#  ('Air Taxi - Petroleum Helicopters Inc.', 15.0),
#  ('Air US / Private', 15.0),
#  ('Bristol Aeroplane Co.', 15.0),
#  ('British European Airways / Military - Soviet Air Force', 15.0),
#  ('Devlet Hava Yollairi', 15.0),
#  ('East Provincial Airways', 15.0),
#  ('Empressa Commun. Aéreas de Veracruz', 15.0),
#  ('Helicopteros Nacionales de Colombia', 15.0),
#  ('Indonesian National Police', 15.0),
#  ('Kirghizia Aba Zaoldoru', 15.0),
#  ('Military - Finish Air Force', 15.0),
#  ('Military - Russian Air Force/Uzbekistan Airways', 15.0),
#  ('Mongolian Defense Ministry', 15.0),
#  ('Nordeste Linhas Aereas', 15.0),
#  ('Norilsk Flight Company', 15.0),
#  ('Panair do Brazil', 15.0),
#  ('Proteus Air / Private', 15.0),
#  ('Réseau Aérien Interinsulaire', 15.0),
#  ('Syktyvkar Avia', 15.0),
#  ('Talia Airways', 15.0),
#  ('Trans World Airlines / Castleton Inc.', 15.0),
#  ('Western Air Express', 15.0),
#  ('AIDA', 14.0),
#  ('Aero Club Libya', 14.0),
#  ('Air Charter', 14.0),
#  ('Air Kasai', 14.0),
#  ('Air South', 14.0),
#  ('Air Taxi - Henson Airlines', 14.0),
#  ('Airtech Rajawaldi Udara', 14.0),
#  ('British European Airways / Military - British', 14.0),
#  ('Burke Air Transport', 14.0),
#  ('CORAL Colombia', 14.0),
#  ('Cessnyca', 14.0),
#  ('Compania de Mexico', 14.0),
#  ('Continental Express', 14.0),
#  ('Cooper Skybird Air Charters', 14.0),
#  ('Copterline', 14.0),
#  ('Eagle Cap Leasing', 14.0),
#  ('Golden West Airlines / Private', 14.0),
#  ('Great Lakes Business Complany', 14.0),
#  ('Indamer', 14.0),
#  ('Japan Air Self-Defence Force', 14.0),
#  ('Jersey Airways', 14.0),
#  ('Kalinin', 14.0),
#  ('Komi Avia', 14.0),
#  ('Military - Fuerza Aérea de Chile', 14.0),
#  ('Military - Kenya Air Force', 14.0),
#  ('Military - Niger Air Force', 14.0),
#  ('Nile Safaris Aviation', 14.0),
#  ('PacifiAir Transport', 14.0),
#  ('PacifiCoastal Airlines', 14.0),
#  ('PacifiNorthern Airlines', 14.0),
#  ('Panagra', 14.0),
#  ('Provincetown - Boston Airlines', 14.0),
#  ('Pulkovo Aviation Enterprise', 14.0),
#  ('Ryan Blake Air Charter', 14.0),
#  ('SADELCA', 14.0),
#  ('Savannair', 14.0),
#  ('Seattle Air Charter', 14.0),
#  ('Skyline Airways', 14.0),
#  ('Societe Transatlantique Aerienne', 14.0),
#  ('Transportes Aereos Pegaso', 14.0),
#  ('Transportes Aéreos Salvador', 14.0),
#  ('United Express  / Private', 14.0),
#  ('Vieques Air Link', 14.0),
#  ('YPFB Transportes Aereos', 14.0),
#  ('Advance Airlines', 13.0),
#  ('Aerotaca', 13.0),
#  ('Air Wisconsin', 13.0),
#  ('Aitalia', 13.0),
#  ('Alaska Aeronautical Industries', 13.0),
#  ('Bradley Air Services', 13.0),
#  ('British Airways', 13.0),
#  ('Caribbean International Airways', 13.0),
#  ('Chicago Helicopter Airways', 13.0),
#  ('Columbia Air Cargo', 13.0),
#  ('Corporate Airlines (American Connection)', 13.0),
#  ('DNL', 13.0),
#  ('Dalmia Jain Airways', 13.0),
#  ('East Indonesia Air Taxi', 13.0),
#  ('Edde Airlines', 13.0),
#  ('Eitos', 13.0),
#  ('Flight Service', 13.0),
#  ('Gira Globo Charter', 13.0),
#  ('Hageland Aviation Services', 13.0),
#  ('IMSS', 13.0),
#  ('International Control Commision', 13.0),
#  ('Island Air', 13.0),
#  ('Islands Nationair', 13.0),
#  ("L'Express Airlines", 13.0),
#  ('Leeward Islands Air Transport', 13.0),
#  ('Lineas Aereas Unidas', 13.0),
#  ('Lockheed AC-130H Hercules', 13.0),
#  ('Macchi', 13.0),
#  ('Mercury Aviation', 13.0),
#  ("Military - Armée de l'Air Malgache", 13.0),
#  ('Military - Fuerza Del Peru', 13.0),
#  ('Military - Government of Equatorial Guinea', 13.0),
#  ('Military - U.S. Army Air Corps', 13.0),
#  ('Military - Zambia Air Force', 13.0),
#  ('National Air Transport Services', 13.0),
#  ('North Central Airlines / Air Wisconsin', 13.0),
#  ('North Western Air Transport', 13.0),
#  ('Okanagan Helicopters', 13.0),
#  ('Private - Ashland Oil Company', 13.0),
#  ('Private - OverteCompany', 13.0),
#  ('SAVCO', 13.0),
#  ('Servicios Aereos Martinez Leon', 13.0),
#  ('TARS', 13.0),
#  ('Trans Continental Air Transport', 13.0),
#  ('TsAGI', 13.0),
#  ('West African Airways', 13.0),
#  ('Yemen Airlines', 13.0),
#  ('Zantop Air Transport', 13.0),
#  ('AV Air / American Eagle', 12.0),
#  ...]

# %% [markdown]
# # Plots!

# %% [markdown]
# ## Number of crashes per year - sorted by year and a bar chart
# http://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.plot.html#pandas.DataFrame.plot
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.sort_index.html?highlight=sort

# %%
ax = df['year'].value_counts().sort_index().plot(kind='bar', figsize=(25, 8), grid=True, color='b')

# %% [markdown]
# ## Number of passengers per year & fatalities in the same plot - sorted by year and line chart

# %%
year_group = df.groupby('year')
year = []
deaths = []
total_pass = []
for name, group in year_group:
    year.append(name)
    deaths.append(group['Fatalities'].sum())
    total_pass.append(group['Aboard'].sum())

plt.figure(figsize=(20, 8))
plt.plot(year, deaths, label='Deaths', marker='o')
plt.plot(year, total_pass, label='Aboard', marker='o')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Plot the total number of accidents of military and regular operators

# %%
df_military_num = len(df[df['Operator'].apply(lambda x: "military" in str(x).lower())])
df_military_non_num = len(df) - df_military_num

objects = ['Military Crashes', 'Non Military crashes']
accidents = [df_military_num, df_military_non_num]
x_coordinates = np.arange(len(objects))

plt.bar(x_coordinates, accidents, align='center', width=0.5) #default width is 0.8
plt.xticks(x_coordinates, objects)
plt.ylabel('Accidents')
plt.title('Military vs Non Military Crashes')
plt.show()

# %% [markdown]
# ## Count of accidents by month

# %%
df['month'].value_counts().sort_index().plot(kind='bar', figsize=(20, 8), grid=True, color='b')
# you can even make all numbers in the month column to Jan, Feb and so on! Just 1 more apply method!

# %% [markdown]
# ## The number of accidents for the operator Aeroflot per year

# %%
df_aeroflot = df[df['Operator'] == 'Aeroflot']
df_aeroflot['year'].value_counts().sort_index().plot(kind='bar', figsize=(20, 8), grid=True, color='b')

# %% [markdown]
# ## Top 10 operators by number of accidents

# %%
df['Operator'].value_counts().head(10).plot(kind='bar', figsize=(20, 8), grid=True, color='b')
